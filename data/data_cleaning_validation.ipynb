# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
from langdetect import detect
from great_expectations.data_context import FileDataContext

# %% [markdown]
# # Load data

# %%
# Menggabungkan data hasil scrapping
df1 = pd.read_csv('job1to5.csv')
df2 = pd.read_csv('job6to7.csv')
df3 = pd.read_csv('job8to10.csv')
df4 = pd.read_csv('job11to15.csv')
df5 = pd.read_csv('job16to20.csv')
df = pd.concat([df1,df2,df3,df4,df5])

# %% [markdown]
# # Cleaning Data

# %%
# Hanya mengambil 61 karakter awal dari urlnya 
df['job_url'] = df['job_url'].str[:61]

# %%
# Cek duplikat dan data yang missing value
print(df.duplicated().sum())
print(df.isna().sum())
# Out:
# 6832
# company_name       435
# job_location       435
# job_title          435
# job_description    435
# job_url            435
# dtype: int64

# %%
# Menghapus data duplikat dan missing value
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)

# %%
# Fungsi untuk mendeteksi bahasa dalam dataset
def detect_lang(text):
    try:
        return detect(text)
    except:
        return "unknown"

# Membuat kolom baru untuk identifikasi bahasanya
df['lang'] = df['job_description'].apply(detect_lang)

# %%
# Menampilkan banyak data dengan bahasa tertentu
df['lang'].value_counts()
# Out:
# lang
# en       3497
# id        427
# vi         12
# zh-cn       8
# de          7
# es          2
# nl          2
# th          1
# fr          1
# ko          1
# Name: count, dtype: int64

# %%
# Hanya mengambil data yang berbahasa inggris
df_en_only = df.query('lang == "en"').reset_index(drop=True)
df_en_only
# Out:
#                           company_name                          job_location  \
# 0                            English 1                    Jakarta, Indonesia
# 1               Path Finder Investment             Jakarta Metropolitan Area
# 2                         deVere Group                    Jakarta, Indonesia
# 3                          Media Minds   Central Jakarta, Jakarta, Indonesia
# 4                                  SLB  North Cikarang, West Java, Indonesia
# ...                                ...                                   ...
# 3492                 PT Good Sale Tech                    Jakarta, Indonesia
# 3493  Triputra Edukasi Nusantara (TEN)         Setiabudi, Jakarta, Indonesia
# 3494              Confidential Careers   Makassar, South Sulawesi, Indonesia
# 3495                      BNI Ventures             Jakarta Metropolitan Area
# 3496                          Club Med     Yogyakarta, Yogyakarta, Indonesia
#
#                                               job_title  \
# 0     Hiring Now! Entry-Level English Teacher (ESL) ...
# 1                                  Marketing Strategist
# 2                  Wealth Management Advisor - Jakarta
# 3                                    Service Technician
# 4                Sales Representative - Valve Services
# ...                                                 ...
# 3492             Talent Acquisition & Employer Branding
# 3493                  Information Technology Specialist
# 3494                              Area Business Manager
# 3495                Marketing & Corporate Communication
# 3496  Assistant Technical Service Manager Club Med R...
#
#                                         job_description  \
# 0     About the job\nJoin English 1 (formerly EF Eng...
# 1     About the job\nMarketing Strategist\nThe Canop...
# 2     About the job\nJoin Our Team as a Financial Sa...
# 3     About the job\nCompany Description\n AAA Tradi...
# 4     About the job\nAbout Us\n\nWe are a global tec...
# ...                                                 ...
# 3492  About the job\nGet To Know Us!\nPT. Good Sale ...
# 3493  About the job\nCompany Description\n Triputra ...
# 3494  About the job\nJob Description\nRepresent the ...
# 3495  About the job\nCompany Description\nBNI Ventur...
# 3496  About the job\nDo you know Club Med? \n\nWe ha...
#
#                                                 job_url lang
# 0     https://www.linkedin.com/jobs/search/?currentJ...   en
# 1     https://www.linkedin.com/jobs/search/?currentJ...   en
# 2     https://www.linkedin.com/jobs/search/?currentJ...   en
# 3     https://www.linkedin.com/jobs/search/?currentJ...   en
# 4     https://www.linkedin.com/jobs/search/?currentJ...   en
# ...                                                 ...  ...
# 3492  https://www.linkedin.com/jobs/search/?currentJ...   en
# 3493  https://www.linkedin.com/jobs/search/?currentJ...   en
# 3494  https://www.linkedin.com/jobs/search/?currentJ...   en
# 3495  https://www.linkedin.com/jobs/search/?currentJ...   en
# 3496  https://www.linkedin.com/jobs/search/?currentJ...   en
#
# [3497 rows x 6 columns]

# %%
# Menyimpan data yang berbahasa inggris ke dalam csv
df_en_only.to_csv('data_clean.csv', index=False)

# %% [markdown]
# # SkillMatch, Data Validation Great Expectations

# %%
context = FileDataContext.create(project_root_dir='./gx_data_context')

# %% [markdown]
# # Connect to data source

# %%
# Give a name to a Datasource. This name must be unique between Datasources.
datasource_name = 'csv-data-job'
datasource = context.sources.add_pandas(datasource_name)

# Give a name to a data asset
asset_name = 'job-november'
path_to_data = 'data_clean.csv'
asset = datasource.add_csv_asset(asset_name, filepath_or_buffer=path_to_data)

# Build batch request
batch_request = asset.build_batch_request()

# %% [markdown]
# # Create Expectation Suite

# %%
# Creat an expectation suite
expectation_suite_name = 'expectation-job-dataset'
context.add_or_update_expectation_suite(expectation_suite_name)

# Create a validator using above expectation suite
validator = context.get_validator(
    batch_request = batch_request,
    expectation_suite_name = expectation_suite_name
)

# Check the validator
validator.head()
# Out:
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
#              company_name                          job_location  \
# 0               English 1                    Jakarta, Indonesia
# 1  Path Finder Investment             Jakarta Metropolitan Area
# 2            deVere Group                    Jakarta, Indonesia
# 3             Media Minds   Central Jakarta, Jakarta, Indonesia
# 4                     SLB  North Cikarang, West Java, Indonesia
#
#                                            job_title  \
# 0  Hiring Now! Entry-Level English Teacher (ESL) ...
# 1                               Marketing Strategist
# 2               Wealth Management Advisor - Jakarta
# 3                                 Service Technician
# 4             Sales Representative - Valve Services
#
#                                      job_description  \
# 0  About the job\nJoin English 1 (formerly EF Eng...
# 1  About the job\nMarketing Strategist\nThe Canop...
# 2  About the job\nJoin Our Team as a Financial Sa...
# 3  About the job\nCompany Description\n AAA Tradi...
# 4  About the job\nAbout Us\n\nWe are a global tec...
#
#                                              job_url lang
# 0  https://www.linkedin.com/jobs/search/?currentJ...   en
# 1  https://www.linkedin.com/jobs/search/?currentJ...   en
# 2  https://www.linkedin.com/jobs/search/?currentJ...   en
# 3  https://www.linkedin.com/jobs/search/?currentJ...   en
# 4  https://www.linkedin.com/jobs/search/?currentJ...   en

# %% [markdown]
# ## Expectations

# %%
# Expectation 1 : Kolom `job_description` harus unik/tidak ada duplicate

validator.expect_compound_columns_to_be_unique(
    column_list=['company_name', 'job_location', 'job_title', 'job_description', 'job_url']
)
# Out:
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# {
#   "success": true,
#   "result": {
#     "element_count": 3497,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": [],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
# Expectation 2 : Kolom `job_description` harus ada pada dataset

validator.expect_column_to_exist(column='job_description')
# Out:
# Calculating Metrics:   0%|          | 0/2 [00:00<?, ?it/s]
# {
#   "success": true,
#   "result": {},
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
# Expectation 3 : Seluruh kolom tidak ada missing value

validator.expect_column_values_to_not_be_null('company_name')
# Out:
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# {
#   "success": true,
#   "result": {
#     "element_count": 3497,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
validator.expect_column_values_to_not_be_null('job_location')
# Out:
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# {
#   "success": true,
#   "result": {
#     "element_count": 3497,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
validator.expect_column_values_to_not_be_null('job_title')
# Out:
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# {
#   "success": true,
#   "result": {
#     "element_count": 3497,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
validator.expect_column_values_to_not_be_null('job_description')
# Out:
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# {
#   "success": true,
#   "result": {
#     "element_count": 3497,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
validator.expect_column_values_to_not_be_null('job_description')
# Out:
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# {
#   "success": true,
#   "result": {
#     "element_count": 3497,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %% [markdown]
# ### Save expectations suite

# %%
# Save into Expectation Suite
validator.save_expectation_suite(discard_failed_expectations=False)

# %% [markdown]
# ## Checkpoint

# %%
# Create a checkpoint

checkpoint_1 = context.add_or_update_checkpoint(
    name = 'checkpoint_1',
    validator = validator,
)

# %%
# Run a checkpoint

checkpoint_result = checkpoint_1.run()
checkpoint_result
# Out:
# Calculating Metrics:   0%|          | 0/29 [00:00<?, ?it/s]
# {
#   "run_id": {
#     "run_name": null,
#     "run_time": "2025-11-07T01:15:39.243307+07:00"
#   },
#   "run_results": {
#     "ValidationResultIdentifier::expectation-job-dataset/__none__/20251106T181539.243307Z/csv-data-job-job-november": {
#       "validation_result": {
#         "success": true,
#         "results": [
#           {
#             "success": true,
#             "expectation_config": {
#               "expectation_type": "expect_compound_columns_to_be_unique",
#               "kwargs": {
#                 "column_list": [
#                   "company_name",
#                   "job_location",
#                   "job_title",
#                   "job_description",
#                   "job_url"
#                 ],
#                 "batch_id": "csv-data-job-job-november"
#               },
#               "meta": {}
#             },
#             "result": {
#               "element_count": 3497,
#               "unexpected_count": 0,
#               "unexpected_percent": 0.0,
#               "partial_unexpected_list": [],
#               "missing_count": 0,
#               "missing_percent": 0.0,
#               "unexpected_percent_total": 0.0,
#               "unexpected_percent_nonmissing": 0.0,
#               "partial_unexpected_counts": [],
#               "partial_unexpected_index_list": []
#             },
#             "meta": {},
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "success": true,
#             "expectation_config": {
#               "expectation_type": "expect_column_to_exist",
#               "kwargs": {
#                 "column": "job_description",
#                 "batch_id": "csv-data-job-job-november"
#               },
#               "meta": {}
#             },
#             "result": {},
#             "meta": {},
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "success": true,
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_not_be_null",
#               "kwargs": {
#                 "column": "job_description",
#                 "batch_id": "csv-data-job-job-november"
#               },
#               "meta": {}
#             },
#             "result": {
#               "element_count": 3497,
#               "unexpected_count": 0,
#               "unexpected_percent": 0.0,
#               "partial_unexpected_list": [],
#               "partial_unexpected_counts": [],
#               "partial_unexpected_index_list": []
#             },
#             "meta": {},
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "success": true,
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_not_be_null",
#               "kwargs": {
#                 "column": "company_name",
#                 "batch_id": "csv-data-job-job-november"
#               },
#               "meta": {}
#             },
#             "result": {
#               "element_count": 3497,
#               "unexpected_count": 0,
#               "unexpected_percent": 0.0,
#               "partial_unexpected_list": [],
#               "partial_unexpected_counts": [],
#               "partial_unexpected_index_list": []
#             },
#             "meta": {},
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "success": true,
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_not_be_null",
#               "kwargs": {
#                 "column": "job_location",
#                 "batch_id": "csv-data-job-job-november"
#               },
#               "meta": {}
#             },
#             "result": {
#               "element_count": 3497,
#               "unexpected_count": 0,
#               "unexpected_percent": 0.0,
#               "partial_unexpected_list": [],
#               "partial_unexpected_counts": [],
#               "partial_unexpected_index_list": []
#             },
#             "meta": {},
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "success": true,
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_not_be_null",
#               "kwargs": {
#                 "column": "job_title",
#                 "batch_id": "csv-data-job-job-november"
#               },
#               "meta": {}
#             },
#             "result": {
#               "element_count": 3497,
#               "unexpected_count": 0,
#               "unexpected_percent": 0.0,
#               "partial_unexpected_list": [],
#               "partial_unexpected_counts": [],
#               "partial_unexpected_index_list": []
#             },
#             "meta": {},
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           }
#         ],
#         "evaluation_parameters": {},
#         "statistics": {
#           "evaluated_expectations": 6,
#           "successful_expectations": 6,
#           "unsuccessful_expectations": 0,
#           "success_percent": 100.0
#         },
#         "meta": {
#           "great_expectations_version": "0.18.22",
#           "expectation_suite_name": "expectation-job-dataset",
#           "run_id": {
#             "run_name": null,
#             "run_time": "2025-11-07T01:15:39.243307+07:00"
#           },
#           "batch_spec": {
#             "reader_method": "read_csv",
#             "reader_options": {
#               "filepath_or_buffer": "data_clean.csv"
#             }
#           },
#           "batch_markers": {
#             "ge_load_time": "20251106T181539.273321Z",
#             "pandas_data_fingerprint": "b317ac370197473e15d377c7dc64a4df"
#           },
#           "active_batch_definition": {
#             "datasource_name": "csv-data-job",
#             "data_connector_name": "fluent",
#             "data_asset_name": "job-november",
#             "batch_identifiers": {}
#           },
#           "validation_time": "20251106T181539.585298Z",
#           "checkpoint_name": "checkpoint_1",
#           "validation_id": null,
#           "checkpoint_id": null
#         }
#       },
#       "actions_results": {
#         "store_validation_result": {
#           "class": "StoreValidationResultAction"
#         },
#         "store_evaluation_params": {
#           "class": "StoreEvaluationParametersAction"
#         },
#         "update_data_docs": {
#           "local_site": "file://d:\\Hactiv8\\final project\\Final project\\Data\\gx_data_context\\gx\\uncommitted/data_docs/local_site/validations%5Cexpectation-job-dataset%5C__none__%5C20251106T181539.243307Z%5Ccsv-data-job-job-november.html",
#           "class": "UpdateDataDocsAction"
#         }
#       }
#     }
#   },
#   "checkpoint_config": {
#     "slack_webhook": null,
#     "site_names": null,
#     "batch_request": {},
#     "expectation_suite_name": null,
#     "module_name": "great_expectations.checkpoint",
#     "default_validation_id": null,
#     "validations": [
#       {
#         "expectation_suite_ge_cloud_id": null,
#         "name": null,
#         "batch_request": {
#           "datasource_name": "csv-data-job",
#           "data_asset_name": "job-november",
#           "options": {},
#           "batch_slice": null
#         },
#         "expectation_suite_name": "expectation-job-dataset",
#         "id": null
#       }
#     ],
#     "name": "checkpoint_1",
#     "config_version": 1.0,
#     "runtime_configuration": {},
#     "profilers": [],
#     "ge_cloud_id": null,
#     "notify_with": null,
#     "evaluation_parameters": {},
#     "notify_on": null,
#     "class_name": "Checkpoint",
#     "expectation_suite_ge_cloud_id": null,
#     "run_name_template": null,
#     "template_name": null,
#     "action_list": [
#       {
#         "name": "store_validation_result",
#         "action": {
#           "class_name": "StoreValidationResultAction"
#         }
#       },
#       {
#         "name": "store_evaluation_params",
#         "action": {
#           "class_name": "StoreEvaluationParametersAction"
#         }
#       },
#       {
#         "name": "update_data_docs",
#         "action": {
#           "class_name": "UpdateDataDocsAction"
#         }
#       }
#     ]
#   },
#   "success": true
# }

# %% [markdown]
# ## Data Docs
# Kemudian data docs akan di buat sehingga dapat ditampilkan pada dashboard yang dapat diakses pada folder `gx_data_context` yang telah di buat pada create data context sebelumnya, tepatnya di direktori `gx_data_context/uncommitted/data_docs/index.html`

# %%
# Build data docs

context.build_data_docs()
# Out:
# {'local_site': 'file://d:\\Hactiv8\\final project\\Final project\\Data\\gx_data_context\\gx\\uncommitted/data_docs/local_site/index.html'}
